# %%
from ultralytics import YOLO

model = YOLO("runs/detect/roskispolis3/weights/best.pt")

model.predict(
    source="torture_test",
    save=True,
    conf=0.25
)
# Out:
# image 1/10 E:\skola\datorseende\datorseende_roskis\torture_test\rn_image_picker_lib_temp_04358516-0236-4122-acfc-89b44ab53e62.jpg: 480x640 3 Konservburks, 2 Pantburks, 124.2ms
# image 2/10 E:\skola\datorseende\datorseende_roskis\torture_test\rn_image_picker_lib_temp_0f42d483-5f45-447e-85a1-f86a8e62af51.jpg: 480x640 1 Konservburk, 2 Pantburks, 46.0ms
# image 3/10 E:\skola\datorseende\datorseende_roskis\torture_test\rn_image_picker_lib_temp_531730ff-52fb-4178-a77f-6ac3f0921f13.jpg: 480x640 5 Pantburks, 41.4ms
# image 4/10 E:\skola\datorseende\datorseende_roskis\torture_test\rn_image_picker_lib_temp_6957f782-5436-453a-8991-b7ed8ab07238.jpg: 640x480 1 Konservburk, 2 Pantburks, 51.6ms
# image 5/10 E:\skola\datorseende\datorseende_roskis\torture_test\rn_image_picker_lib_temp_80f8229c-3d7c-426b-be0c-ffaa1dd88c92.jpg: 640x480 3 Konservburks, 2 Pantburks, 43.0ms
# ...
