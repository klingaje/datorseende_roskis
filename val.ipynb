# %%
from ultralytics import YOLO

model = YOLO("runs/detect/roskispolis3/weights/best.pt")

metrics = model.val(
    data="mydataset.yaml",
    split="test"
)
# Out:
# Ultralytics 8.4.19  Python-3.10.19 torch-2.10.0+cpu CPU (Intel Core i7-9700K 3.60GHz)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.20.1 ms, read: 298.238.3 MB/s, size: 5130.0 KB)
# val: Scanning E:\skola\datorseende\datorseende_roskis\data\test\labels... 54 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 54/54 178.8it/s 0.3s.1s
# val: E:\skola\datorseende\datorseende_roskis\data\test\images\2007308e-nico_5.jpg: 1 duplicate labels removed
# val: E:\skola\datorseende\datorseende_roskis\data\test\images\5e69351c-KimiDo_23.jpg: corrupt JPEG restored and saved
# val: E:\skola\datorseende\datorseende_roskis\data\test\images\9db6824e-AntonDoep_30.jpg: corrupt JPEG restored and saved
# val: E:\skola\datorseende\datorseende_roskis\data\test\images\cb5cfdd2-Max_Roos_26.jpg: corrupt JPEG restored and saved
# ...
